# %%
import pandas as pd
import numpy as np

# %%
# Determines the distance between UMASS-DGI_65 and EEE029, the two isolates used for the first round testing of Nanopore data assembly and polishing methods.
# Note that this includes regions with recombination (i.e. it does NOT remove recombination)

# Load information on pseudogenome distances
df = pd.read_csv('../../../opa_diversity_snakemake/results/pairwise_distance/pseudogenome_distances.csv', index_col = 0, header = None)

# Determine the position of EEE02
idx = np.where(df.index == 'EEE029')[0][0]

# Get the value in the corresponding column in the row of UMASS-DGI_65 (distance between the two isolates)
df[df.index == 'UMASS-DGI_65'].values[0][idx]
# Out:
# 6648
